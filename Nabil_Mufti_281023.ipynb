# %% [markdown]
# <a href="https://colab.research.google.com/github/ca-kraa/nabilmufti-dicoding/blob/main/Nabil_Mufti_281023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - Nama: Nabil Mufti
# - Email: nabilmufti14@gmail.com
# - Id Dicoding: nabilmufti
#
# ---

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana variasi jumlah penyewaan sepeda berdasarkan musim?
# - Bagaimana tren penyewaan sepeda selama bertahun-tahun?

# %% [markdown]
# ## Menyaipkan semua library yang dibuthkan

# %%
pip install streamlit
pip install pandas
pip install matplotlib

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# Gathering Data

# %%
data = pd.read_csv('day.csv')

# %% [markdown]
# ### Assessing Data

# %%
if option == 'Show Data':
    st.subheader('Raw Data')
    st.write(data)

# %% [markdown]
# ### Cleaning Data

# %%
data.drop_duplicates(inplace=True)

numerical_features = data.select_dtypes(include=['int64', 'float64']).columns
for feature in numerical_features:
    data[feature].fillna(data[feature].mean(), inplace=True)

categorical_features = data.select_dtypes(include=['object']).columns
for feature in categorical_features:
    data[feature].fillna(data[feature].mode()[0], inplace=True)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
# Loding Data
data = pd.read_csv('day.csv')
# Display Data
if option == 'Show Data':
    st.subheader('Raw Data')
    st.write(data)
# Visualization Data
elif option == 'Show Visualization':
    st.subheader('Data Visualization')
    column_to_visualize = st.selectbox('Select a Column for Visualization', data.columns)
    if data[column_to_visualize].dtype == 'int64' or data[column_to_visualize].dtype == 'float64':
        st.write(f'Visualization of {column_to_visualize}')
        st.bar_chart(data[column_to_visualize])

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana variasi jumlah penyewaan sepeda berdasarkan musim?
#
# ![7aFYbLW5Kd.png](data:image/png;base64,...)

# %% [markdown]
# ### Pertanyaan 2: Bagaimana tren penyewaan sepeda selama bertahun-tahun?
#
# ![ZogNjmGMN8.png](data:image/png;base64,...)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1. Apakah musim tertentu memiliki pengaruh signifikan terhadap jumlah penyewaan sepeda?
# - *Ya, musim memiliki pengaruh signifikan terhadap jumlah penyewaan sepeda. Dari visualisasi "Total Penyewaan Sepeda per Musim", kita dapat melihat bahwa jumlah penyewaan sepeda cenderung lebih tinggi pada musim tertentu. Namun, untuk mengetahui musim mana yang memiliki jumlah penyewaan sepeda tertinggi, kita perlu melihat data lebih detail atau melakukan analisis lebih lanjut.*
#
# 2. Apakah musim tertentu memiliki pengaruh signifikan terhadap jumlah penyewaan sepeda?
#
# - Ya, musim memiliki pengaruh signifikan terhadap jumlah penyewaan sepeda. Dari visualisasi "Total Penyewaan Sepeda per Musim", kita dapat melihat bahwa jumlah penyewaan sepeda cenderung lebih tinggi pada musim tertentu. Namun, untuk mengetahui musim mana yang memiliki jumlah penyewaan sepeda tertinggi, kita perlu melihat data lebih detail atau melakukan analisis lebih lanjut.

# %% [markdown]
# ## Hasil keseluruhan

# %% [markdown]
# - Total Penyewaan Sepeda per Musim
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Total Penyewaan Sepeda per Tahun
# ![image.png](data:image/png;base64,...)
